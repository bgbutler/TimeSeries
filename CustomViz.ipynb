# %%
import pandas as pd
import os


# %matplotlib inline

# %%
# create the path for the file

myPath = os.path.join('/Users', 'Bryan', 'Documents', 'Programming', 'time_series_forecasting_with_python', 'UDEMY_TSA_FINAL', '03-Pandas-Visualization')

print(myPath)

os.chdir(myPath)
# Out:
# /Users/Bryan/Documents/Programming/time_series_forecasting_with_python/UDEMY_TSA_FINAL/03-Pandas-Visualization

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2['c'].plot.line(figsize = (20, 6), ls = ':', c = 'red', lw = 5)

# %%
title = "MY PLOT TITLE"
xlabel = 'X Data'
ylabel = 'Y Data'

# %%
ax = df2['c'].plot.line(figsize = (20, 6), ls = ':', c = 'red', lw = 5, title = title)
ax.set(xlabel = xlabel, ylabel = ylabel)
# Out:
# [Text(0,0.5,'Y Data'), Text(0.5,0,'X Data')]

# %%
ax = df2.plot(figsize = (20, 6))
ax.legend(loc = 4)

# %%
# move legend outside plot
ax = df2.plot(figsize = (10, 6))
ax.legend(loc = 0, bbox_to_anchor = (1.0, 0.5))
