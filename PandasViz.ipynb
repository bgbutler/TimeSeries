# %%
import pandas as pd
import os


# %matplotlib inline

# %%
# create the path for the file

myPath = os.path.join('/Users', 'Bryan', 'Documents', 'Programming', 'time_series_forecasting_with_python', 'UDEMY_TSA_FINAL', '03-Pandas-Visualization')

print(myPath)

os.chdir(myPath)
# Out:
# /Users/Bryan/Documents/Programming/time_series_forecasting_with_python/UDEMY_TSA_FINAL/03-Pandas-Visualization

# %%
df1 = pd.read_csv('df1.csv', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
# plot a histogram
df1['A'].plot.hist();

# %%
df1['A'].plot.hist(bins = 25, edgecolor = 'k', grid = True).autoscale(enable = True, axis = 'both', tight = True)

# %%
figsize = (12,10)

df2.plot.bar(stacked = True, figsize = (12,8))

# %%
df2.plot.barh(stacked = True)

# %%
df2.plot.line(y = ['a', 'b', 'c'], figsize = (12,8), lw = 4)

# %%
df2.plot.area(figsize = (10,6), stacked= False, alpha = 0.4)

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', figsize = (12,8), cmap = 'coolwarm')

# %%
df1.plot.scatter(x = 'A', y = 'B', s=df1['C'] * 50 , figsize = (12,8), alpha = 0.3)
# Out:
# /Users/Bryan/anaconda/lib/python3.6/site-packages/matplotlib/collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box(figsize = (12, 8), grid = True)

# %%
df2.plot.kde(figsize = (12, 8))

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000,2), columns = ['a', 'b'])

# %%
df.plot.scatter(x = 'a', y = 'b', figsize = (12, 8))

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 20, figsize = (12, 8), cmap = 'coolwarm')
